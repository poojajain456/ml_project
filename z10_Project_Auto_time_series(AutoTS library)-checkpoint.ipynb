# %%
# !pip install autots
# Out:
# ...
#   Obtaining dependency information for autots from https://files.pythonhosted.org/packages/80/f6/40433a15a07dae2fd50816d9a42e68c91499af6af4e782cde6dceb3fc0ec/autots-0.6.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/765.3 kB ? eta -:--:--
#    --- ------------------------------------ 61.4/765.3 kB 1.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 450.6/765.3 kB 7.0 MB/s eta 0:00:01
#    ------------------------------------ --- 706.6/765.3 kB 8.8 MB/s eta 0:00:01
#    ------------------------------------ --- 706.6/765.3 kB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  757.8/765.3 kB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 765.3/765.3 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd

# %%
from autots import AutoTS

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\pujaj\\Downloads\\ML Data\\AAPL.csv")

# %%
df=df[["Date","Close"]]
df["Date"]=pd.to_datetime(df.Date)
df["Close"].plot(figsize=(12,8),title="Apple stock Prices",fontsize=20,label="Close Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Now let's see how to use the AutoTS library for the task on automatic time series forcasting

# %%
from autots import AutoTS

# %%
model=AutoTS(forecast_length=10,frequency='infer',
            ensemble='simple',drop_data_older_than_periods=200)
model=model.fit(df,date_col='Date',value_col='Close',id_col=None)
# Out:
# Data frequency is: B, used frequency is: B
# Old data dropped by `drop_data_older_than_periods`.
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# C:\Users\pujaj\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\pujaj\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %% [markdown]
# # from autots import AutoTS:- this line imports a module called AutoTS  from a library. AutoTS is a tool for automatic time series forecasting, which means it can predict future values in a time- ordered datasets
#
# model=AutoTS(forecast_length=10,frequency='infer',ensemble='simple',drop_data_older_than_periods=200): here a forecasting model is created and assigned to the variable model. let's look at the parameters.
#
# frequency='infer': this parameter specifies the time frequency of your data. infer means the AutoTS will try to automaticallu=y determine it's using a basic
#
# ensemble='simple':- this parameter specifies the type of ensemble model to use. in this case ,it's set to simple ,which likely means its using a basic ensemble approach for combining multiple forecasting methods.
#
# drop_data:-

# %%
prediction=model.predict()
forecast=prediction.forecast
print("stock price prediction of Apple")
print(forecast)
# Out:
# stock price prediction of Apple
#                  Close
# 2021-04-19  135.613609
# 2021-04-20  135.580840
# 2021-04-21  135.491653
# 2021-04-22  134.716009
# 2021-04-23  134.423659
# 2021-04-26  133.997074
# 2021-04-27  133.593175
# 2021-04-28  133.896936
# 2021-04-29  134.949025
# 2021-04-30  135.043534
